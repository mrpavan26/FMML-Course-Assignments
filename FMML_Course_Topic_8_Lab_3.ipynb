# %% [markdown]
# <a href="https://colab.research.google.com/github/mrpavan26/FMML-Course-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-20 12:30:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   130MB/s    in 0.5s
#
# 2024-04-20 12:30:25 (130 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4533    0902.3430v2  This paper addresses the general problem of do...    cs
# 12319  1711.08095v2  Motivation: How do we integratively analyze la...    cs
# 30834  1801.05585v1  In this work we propose Pixel Content Encoders...    cs
# 4810   1511.03816v6  Most machine learning models are static, but t...    cs
# 7113   1710.05741v2  This paper takes a step towards temporal reaso...  stat
# ...             ...                                                ...   ...
# 15700  1602.04427v2  There is a wealth of information about financi...    cs
# 26799  1611.09053v1  Despite the recent success of neural networks ...    cs
# 18350   0904.3701v1  Social Network Analysis (SNA) tries to underst...    cs
# 38120   1406.3915v1  The paper presents the capability of an HMM-ba...    cs
# 20626  1608.05694v1  In this paper we discuss methods of using the ...    cs
#
#                                                    title  year  \
# 4533   Domain Adaptation: Learning Bounds and Algorithms  2009
# 12319  SNeCT: Scalable network constrained Tucker dec...  2017
# 30834  Light-weight pixel context encoders for image ...  2018
# 4810                        Characterizing Concept Drift  2015
# 7113   A Disentangled Recognition and Nonlinear Dynam...  2017
# ...                                                  ...   ...
# 15700  Exploiting Lists of Names for Named Entity Ide...  2016
# 26799  Bidirectional Multirate Reconstruction for Tem...  2016
# 18350                   Semantic Social Network Analysis  2009
# 38120        A Bengali HMM Based Speech Synthesis System  2014
# 20626  The languages of actions, formal grammars and ...  2016
#
#                                                 keywords
# 4533   [addresses, adaptation, applications, distribu...
# 12319  [motivation, integratively, dimensional, furth...
# 30834  [inpainting, generating, previously, presented...
# 4810   [increasing, deployment, increasing, developme...
# 7113   [reasoning, dynamically, constitutes, describe...
# ...                                                  ...
# 15700  [information, financial, collections, speciali...
# 26799  [sufficient, information, unsupervised, untrim...
# 18350  [understand, evolution, increasingly, classica...
# 38120  [capability, synthesis, trajectories, paramete...
# 20626  [languages, qualitative, conceptual, linguisti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4533     [addresses, adaptation, applications, distribu...
# 12319    [motivation, integratively, dimensional, furth...
# 30834    [inpainting, generating, previously, presented...
# 4810     [increasing, deployment, increasing, developme...
# 7113     [reasoning, dynamically, constitutes, describe...
#                                ...
# 6048     [understanding, designers, selection, engineer...
# 23451    [extensive, dedicated, retrieval, attracted, a...
# 15929    [accurately, predicting, difficulty, sentences...
# 13576    [evolutionary, algorithms, heuristic, algorith...
# 11744    [automated, prediction, challenging, distincti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ff520fbb-d247-4bbd-84db-c0ee4bc688f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff520fbb-d247-4bbd-84db-c0ee4bc688f6")) {                    Plotly.newPlot(                        "ff520fbb-d247-4bbd-84db-c0ee4bc688f6",                        [{"x":["motivates","estimating","available","minimizing","applications","functions","generalization","addresses","different","regularization","arbitrary","demonstrate","including","minimization","complexity","distributions","rademacher","empirical","distribution","experiments","adaptation","preliminary","algorithms","discrepancy","introduce","regression","generated","observations","clustered","interpretation","dimensional","constructed","interesting","illustration","decomposition","respectively","illustrate","subclasses","stochastic","personalized","separation","motivation","furthermore","stratification","optimization","similarity","correlation","decomposed","knowledge","interpretable","integrative","association","constrained","incorporate","parallelizable","precision","systematically","trainable","incorporating","information","magnitude","convolutional","convolutions","presented","paintings","architecture","previously","achieving","generating","performance","benchmark","inpainting","extrapolation","boundaries","parameters","particular","objective","descriptions","foundation","qualitative","comprehensive","ambiguities","increasing","subjected","understanding","mechanisms","characterizing","framework","quantitative","deployment","efficient","effective","development","definition","definitions","stationary","unsupervised","reasoning","disentangles","sequential","dynamically","imputation","constitutes","competing","disentangled","describes","variational","nonlinear","simulated","outperforms","representation","generative","evolution","recognition","representations","describing","invertible","represent","embedding","exploiting","prediction","constraints","comparative","corrupted","likelihood","estimator","comparisons","relationship","reversing","constraint","probability","investigate","characterize","euclidean","evaluated","corresponding","independently","contributions","situation","variation","judgments","structured","nonparametric","integrate","extracting","algorithm","heterogeneously","demonstrates","retrieval","theoretic","widespread","introduces","calculated","relevance","indicators","operators","posterior","technique","databases","searching","predictive","probabilistic","evaluators","multivariate","difficult","macroeconomic","uninformative","programming","substantial","considered","accounted","specified","developed","inability","quantification","conducted","outperform","quantifying","generation","intervals","predictions","principle","ensembled","uncertainty","axiomatic","limitations","distributional","assumption","capturing","dialectal","detection","identification","approaches","classifiers","classifier","broadcast","discriminate","switching","automatic","validated"],"y":[6,53,303,53,429,230,107,64,737,95,74,566,259,72,227,115,6,171,215,587,64,45,581,12,315,98,174,60,17,61,182,51,71,2,62,107,70,4,127,21,26,27,153,2,345,157,81,7,319,36,3,29,65,65,4,93,28,19,58,654,56,348,10,197,9,226,109,77,94,869,197,10,3,41,259,263,165,32,15,48,58,4,101,6,159,46,12,549,72,25,405,252,116,50,21,27,152,139,1,89,27,3,8,23,4,80,45,55,72,252,347,104,64,384,246,33,3,115,125,89,226,153,41,20,66,27,34,76,0,87,156,140,54,31,153,128,46,54,31,64,6,104,19,39,67,806,1,44,111,48,20,91,23,39,6,36,32,261,55,22,46,155,3,20,165,1,3,115,47,135,5,26,181,5,14,78,112,12,133,9,83,60,0,64,9,55,21,67,38,3,348,113,427,101,159,4,13,19,179,34],"type":"bar"},{"x":["motivates","estimating","available","minimizing","appli ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Gravitational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>A</span> <span style=''>Simple</span> <span style=''>Robust</span> <span style=''>and</span> <span style=''>Adaptive</span> <span style=''>Approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.4056847545219638);'>processing</span> <span style=''>for</span> <span style=''>wireless</span> <span style=''>sensor</span> <span style=''>networks</span> <span style=''>enables</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.30097087378640763);'>different</span> <span style=''>devices</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>cooperate</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(0, 255, 0, 0.30097087378640763);'>different</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.4056847545219638);'>processing</span> <span style=''>tasks</span> <span style=''>A</span> <span style=''>crucial</span> <span style=''>first</span> <span style=''>step</span> <span style=''>is</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>the</span> <span style=''>question</span> <span style=''>who</span> <span style=''>observes</span> <span style=''>what</span> <span style=''>Recently</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>which</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>signalobject</span> <span style='background-color:rgba(0, 255, 0, 0.8461538461538461);'>labelling</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>analysis</span> <span style=''>after</span> <span style='background-color:rgba(0, 255, 0, 0.5402298850574713);'>extracting</span> <span style=''>source</span> <span style=''>specific</span> <span style=''>features</span> <span style=''>however</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>known</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Gravitational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>(GC)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptively</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>physical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>gravitational</span> <span style=''>force</span> <span style=''>be ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>New</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perspectives</span> <span style=''>on</span> <span style=''>k</span> <span style=''>Support</span> <span style=''>and</span> <span style=''>Cluster</span> <span style=''>Norms</span> <br/><br/><span style=''>The</span> <span style=''>k</span> <span style=''>support</span> <span style=''>norm</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizer</span> <span style=''>which</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>sparse</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style=''>norms</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>infimum</span> <span style=''>over</span> <span style=''>quadratics</span> <span style=''>We</span> <span style=''>further</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>k</span> <span style=''>support</span> <span style=''>norm</span> <span style=''>to</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>cluster</span> <span style=''>norm</span> <span style=''>Using</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proximity</span> <span style=''>operator</span> <span style=''>of</span> <span style=''>both</span> <span style=''>norms</span> <span style=''>This</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>k</span> <span style=''>support</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>norm</span> <span style=''>We</span> <span style=''>also</span> <span style=''>describe</span> <span style=''>how</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>problems</span> <span style=''>which</span> <span style=''>employ</span> <span style=''>centered</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>these</span> <span style=''>norms</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>apply</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>via</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>settings</span> <span style=''>Without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruptions</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.32307692307692315);'>completion</span> <span style=''>problem</span> <span style=''>From</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3263157894736842);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>standpoint</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>has</span> <span style=''>been</span> <span style=''>recently</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>when</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>(how</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>observations</span> <span style=''>do</span> <span style=''>we</span> <span style=''>need</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruptions</span> <span style=''>can</span> <span style=''>we</span> <span style=''>tolerate)</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>by</span> <span style=''>now</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>and</span> <span style=''>analyzes</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>greatly</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>above</span> <span style=''>problems</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>observed</span> <span style=''>case</span> <span style=''>with</span> <span style=''>r</span> <span style=''>denoting</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3205741626794259);'>dimension</span> <span style=''>we</span> <span style=''>reduce</span> <span style=''>the</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>In</span> <span style=''>All</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style=''>Deep</span> <span style=''>Belief</span> <span style=''>Is</span> <span style=''>Not</span> <span style=''>Enough</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>models</span> <span style=''>of</span> <span style=''>natural</span> <span style=''>stimuli</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fields</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroscience</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitatively</span> <span style=''>assess</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>is</span> <span style=''>given</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>One</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>which</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>gained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>are</span> <span style=''>deep</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>Analyses</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>however</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>limited</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>qualitative</span> <span style=''>analyses</span> <span style=''>based</span> <span style=''>on</span> <span style=''>samples</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>circumstances</span> <span style=''>the</span> <span style=''>present</span> <span style=''>article</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>th ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.2332382310984308)
# 	reasoning (0.049572039942938656)
# 	architecture (0.08059914407988587)
# 	segmentation (0.06562054208273894)
# 	challenging (0.09914407988587731)
# 	experimental (0.1433666191155492)
# 	different (0.2628388017118402)
# 	detection (0.12410841654778887)
# 	convolutional (0.12410841654778887)
# 	recognition (0.1369472182596291)
#
# Some Statistics words are:
# 	stochastic (0.13527054108216433)
# 	variables (0.13577154308617234)
# 	estimation (0.17234468937875752)
# 	theoretical (0.15430861723446893)
# 	statistical (0.15781563126252504)
# 	algorithm (0.3972945891783567)
# 	inference (0.19188376753507014)
# 	distribution (0.19138276553106212)
# 	dimensional (0.18687374749498997)
# 	regression (0.18537074148296592)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16da1bc7-b32a-4d5d-b813-52cd7eec0ce6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16da1bc7-b32a-4d5d-b813-52cd7eec0ce6")) {                    Plotly.newPlot(                        "16da1bc7-b32a-4d5d-b813-52cd7eec0ce6",                        [{"x":["motivates","estimating","available","minimizing","applications","functions","generalization","addresses","different","regularization","arbitrary","demonstrate","including","minimization","complexity","distributions","rademacher","empirical","distribution","experiments","adaptation","preliminary","algorithms","discrepancy","introduce","regression","generated","observations","clustered","interpretation","dimensional","constructed","interesting","illustration","decomposition","respectively","illustrate","subclasses","stochastic","personalized","separation","motivation","furthermore","stratification","optimization","similarity","correlation","decomposed","knowledge","interpretable","integrative","association","constrained","incorporate","parallelizable","precision","systematically","trainable","incorporating","information","magnitude","convolutional","convolutions","presented","paintings","architecture","previously","achieving","generating","performance","benchmark","inpainting","extrapolation","boundaries","parameters","particular","objective","descriptions","foundation","qualitative","comprehensive","ambiguities","increasing","subjected","understanding","mechanisms","characterizing","framework","quantitative","deployment","efficient","effective","development","definition","definitions","stationary","unsupervised","reasoning","disentangles","sequential","dynamically","imputation","constitutes","competing","disentangled","describes","variational","nonlinear","simulated","outperforms","representation","generative","evolution","recognition","representations","describing","invertible","represent","embedding","exploiting","prediction","constraints","comparative","corrupted","likelihood","estimator","comparisons","relationship","reversing","constraint","probability","investigate","characterize","euclidean","evaluated","corresponding","independently","contributions","situation","variation","judgments","structured","nonparametric","integrate","extracting","algorithm","heterogeneously","demonstrates","retrieval","theoretic","widespread","introduces","calculated","relevance","indicators","operators","posterior","technique","databases","searching","predictive","probabilistic","evaluators","multivariate","difficult","macroeconomic","uninformative","programming","substantial","considered","accounted","specified","developed","inability","quantification","conducted","outperform","quantifying","generation","intervals","predictions","principle","ensembled","uncertainty","axiomatic","limitations","distributional","assumption","capturing","dialectal","detection","identification","approaches","classifiers","classifier","broadcast","discriminate","switching","automatic","validated","variables","diagnostic","tabulated","conclusions","correctly","evaluations","complexes","confidence","extraction","comprehensible","classified","understand","decisions","represented","instances","adequately","researches","interested","incomplete","nonsymbolic","completely","segmentation","tokenization","availability","denoising","computing","simulation","generalized","description","possibility","discussed","implement","conditions","interdisciplinary","described","explicitly","backgrounds","consciousness","reference","introduced","dependence","processes","conscious","auxiliary","classification","predicted","correspond","anonymized","theoretical","organizations","adversarial","procedure","motivated","sensitive","s ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reversing
# 	ensembled
# 	anonymized
# 	anonymization
# 	frequentist
# 	nonconjugate
# 	combinatorially
# 	underpowered
# 	precautions
# 	abandonment
# 	reminiscent
# 	nonparanormal
# 	exponents
# 	penalization
# 	autocorrelation
# 	reconcile
# 	emphstatistical
# 	calculates
# 	dobrushins
# 	maximising
# Some words which never appear in Statistics papers:
# 	subclasses
# 	stratification
# 	paintings
# 	subjected
# 	evaluators
# 	dialectal
# 	tabulated
# 	nonsymbolic
# 	tokenization
# 	consciousness
# 	conscious
# 	nondifferentiable
# 	concreteness
# 	euclidian
# 	insufficiently
# 	perceivable
# 	responsive
# 	registers
# 	discourse
# 	argumentation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067861087249969e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
